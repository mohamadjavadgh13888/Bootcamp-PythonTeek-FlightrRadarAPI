# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamadjavadgh13888/Bootcamp-PythonTeek-FlightrRadarAPI/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install FlightRadarAPI
# Out:
# Collecting FlightRadarAPI
#   Downloading flightradarapi-1.3.10-py3-none-any.whl (13 kB)
# Collecting brotli (from FlightRadarAPI)
#   Downloading Brotli-1.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from FlightRadarAPI) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->FlightRadarAPI) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->FlightRadarAPI) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->FlightRadarAPI) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->FlightRadarAPI) (2023.7.22)
# Installing collected packages: brotli, FlightRadarAPI
# Successfully installed FlightRadarAPI-1.3.10 brotli-1.0.9

# %%
# Define our main tools:
from FlightRadar24.api import FlightRadar24API
fr_api = FlightRadar24API()

# Definition of tools used in reading images
from PIL import Image
import requests
from io import BytesIO

# This library will be used to display images
from matplotlib import pyplot as plt

# Map tool
import folium

# %%
b=36.31481165562254, 59.58604831371066
flights = fr_api.get_flights("IRM")

# %%
flights
# Out:
# [<(A343) EP-MMA - Altitude: 4300 - Ground Speed: 226 - Heading: 285>,
#  <(RJ1H) EP-MOI - Altitude: 25025 - Ground Speed: 368 - Heading: 6>,
#  <(A346) EP-MMQ - Altitude: 35975 - Ground Speed: 478 - Heading: 359>]

# %%
flight=flights[0]
flight_details = fr_api.get_flight_details(flight)

# %%
flight_details
# Out:
# {'identification': {'id': '3198b367',
#   'row': 5395781005,
#   'number': {'default': 'W563', 'alternative': None},
#   'callsign': 'IRM063'},
#  'status': {'live': True,
#   'text': 'Estimated- 12:10',
#   'icon': 'green',
#   'estimated': None,
#   'ambiguous': False,
#   'generic': {'status': {'text': 'estimated',
#     'color': 'green',
#     'type': 'arrival'},
#    'eventTime': {'utc': 1692087033, 'local': 1692101433}}},
#  'level': 'limited',
#  'promote': False,
#  'aircraft': {'model': {'code': 'A343', 'text': 'Airbus A340-311'},
#   'countryId': 104,
#   'registration': 'EP-MMA',
#   'age': None,
#   'msn': None,
#   'images': {'thumbnails': [{'src': 'https://cdn.jetphotos.com/200/6/622078_1690433178_tb.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/11042464',
#      'copyright': 'Oleg Chaplin',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/200/5/792479_1686346202_tb.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10994154',
#      'copyright': 'Mikhail Tambovtsev',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/200/5/939028_1686351203_tb.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10994181',
#      'copyright': 'YaleYeYe-Beijing',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/200/5/811358_1683346808_tb.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10961327',
#      'copyright': 'SANMANCEO',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/200/5/573316_1683201973_tb.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10959738',
#      'copyright': 'PEK FLYER',
#      'source': 'Jetphotos'}],
#    'medium': [{'src': 'https://cdn.jetphotos.com/400/6/622078_1690433178.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/11042464',
#      'copyright': 'Oleg Chaplin',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/400/5/792479_1686346202.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10994154',
#      'copyright': 'Mikhail Tambovtsev',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/400/5/939028_1686351203.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10994181',
#      'copyright': 'YaleYeYe-Beijing',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/400/5/811358_1683346808.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10961327',
#      'copyright': 'SANMANCEO',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/400/5/573316_1683201973.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10959738',
#      'copyright': 'PEK FLYER',
#      'source': 'Jetphotos'}],
#    'large': [{'src': 'https://cdn.jetphotos.com/640cb/6/622078_1690433178.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/11042464',
#      'copyright': 'Oleg Chaplin',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/640cb/5/792479_1686346202.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10994154',
#      'copyright': 'Mikhail Tambovtsev',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/640cb/5/939028_1686351203.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10994181',
#      'copyright': 'YaleYeYe-Beijing',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/640cb/5/811358_1683346808.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10961327',
#      'copyright': 'SANMANCEO',
#      'source': 'Jetphotos'},
#     {'src': 'https://cdn.jetphotos.com/640cb/5/573316_1683201973.jpg?v=0',
#      'link': 'https://www.jetphotos.com/photo/10959738',
#      'copyright': 'PEK FLYER',
#      'source': 'Jetphotos'}]},
#   'hex': '7335a1'},
#  'airline': {'name': 'Mahan Air',
#   'short': 'Mahan Air',
#   'code': {'iata': 'W5', 'icao': 'IRM'},
#   'url': 'mahan-air-irm'},
#  'owner': None,
#  'airspace': None,
#  'airport': {'origin': {'name': 'Tehran Imam Khomeini International Airport',
#    'code': {'iata': 'IKA', 'icao': 'OIIE'},
#    'position': {'latitude': 35.416111,
#     'longitude': 51.152222,
#     'altitude': 3305,
#     'country': {'id': 104, 'name': 'Iran', 'code': 'IR', 'codeLong': 'IRN'},
#     'region': {'city': 'Tehran'}},
#    'timezone': {'name': 'Asia/Tehran',
#     'offset': 12600,
#     'offsetHours': '3:30',
#     'abbr': '+0330',
#     'abbrName': '',
#     'isDst': False},
#    'visible': True,
#    'website': None,
#    'info': {'terminal': None, 'baggage': None, 'gate': None}},
#   'destination': {'name': 'Dubai International Airport',
#    'code': {'iata': 'DXB', 'icao': 'OMDB'},
#    'position': {'latitude': 25.252769,
#     'longitude': 55.364441,
#     'altitude': 62,
#     'country': {'id': 234,
#      'name': 'United Arab Emirates',
#      'code': 'AE',
#      'codeLong': 'ARE'},
#     'region': {'city': 'Dubai'}},
#    'timezone': {'name': 'Asia/Dubai',
#     'offset': 14400,
#     'offsetHours': '4:00',
#     'abbr': '+04',
#     'abbrName': '',
#     'isDst': False},
#    'visible': True,
#    'website': 'https://www.dubaiairports.ae/',
#    'info': {'terminal': '1', 'baggage': '03', 'gate': None}},
#   'real': None},
#  'flightHistory': {'aircraft': [{'identification': {'id': '319714e1',
#      'number': {'default': 'W5115'}},
#     'airport': {'origin': {'name': 'Istanbul Airport',
#       'code': {'iata': 'IST', 'icao': 'LTFM'},
#       'position': {'latitude': 41.267052,
#        'longitude': 28.729757,
#        'altitude': 325,
#        'country': {'id': 228,
#         'name': 'Turkey',
#         'code': 'TR',
#         'codeLong': 'TUR'},
#        'region': {'city': 'Istanbul'}},
#       'timezone': {'name': 'Europe/Istanbul',
#        'offset': 10800,
#        'offsetHours': '3:00',
#        'abbr': '+03',
#        'abbrName': '',
#        'isDst': False},
#       'visible': True,
#       'website': None},
#      'destination': {'name': 'Tehran Imam Khomeini International Airport',
#       'code': {'iata': 'IKA', 'icao': 'OIIE'},
#       'position': {'latitude': 35.416111,
#        'longitude': 51.152222,
#        'altitude': 3305,
#        'country': {'id': 104, 'name': 'Iran', 'code': 'IR', 'codeLong': 'IRN'},
#        'region': {'city': 'Tehran'}},
#       'timezone': {'name': 'Asia/Tehran',
#        'offset': 12600,
#        'offsetHours': '3:30',
#        'abbr': '+0330',
#        'abbrName': '',
#        'isDst': False},
#       'visible': True,
#       'website': None}},
#     'time': {'real': {'departure': 1692037174}}},
#    {'identification': {'id': '31961f16', 'number': {'default': 'W5114'}},
#     'airport': {'origin': {'name': 'Tehran Imam Khomeini International Airport',
#       'code': {'iata': 'IKA', 'icao': 'OIIE'},
#       'position': {'latitude': 35.416111,
#        'longitude': 51.152222,
#        'altitude': 3305,
#        'country': {'id': 104, 'name': 'Iran', 'code': 'IR', 'codeLong': 'IRN'},
#        'region': {'city': 'Tehran'}},
#       'timezone': {'name': 'Asia/Tehran',
#        'offset': 12600,
#        'offsetHours': '3:30',
#        'abbr': '+0330',
#        'abbrName': '',
#        'isDst': False},
#       'visible': True,
#       'website': None},
#      'destination': {'name': 'Istanbul Airport',
#       'code': {'iata': 'IST', 'icao': 'LTFM'},
#       'position': {'latitude': 41.267052,
#        'longitude': 28.729757,
#        'altitude': 325,
#        'country': {'id': 228,
#         'name': 'Turkey',
#         'code': 'TR',
#         'codeLong': 'TUR'},
#        'region': {'city': 'Istanbul'}},
#       'timezone': {'name': 'Europe/Istanbul',
#        'offset': 10800,
#        'offsetHours': '3:00',
#        'abbr': '+03',
#        'abbrName': '',
#        'isDst': False},
#       'visible': True,
#       'website': None}},
#     'time': {'real': {'departure': 1692019263}}},
#    {'identification': {'id': '31954b1e', 'number': {'default': 'W5113'}},
#     'airport': {'origin': {'name': 'Istanbul Airport',
#       'code': {'iata': 'IST', 'icao': 'LTFM'},
#       'position': {'latitude': 41.267052,
#        'longitude': 28.729757,
#        'altitude': 325,
#        'country': {'id': 228,
#         'name': 'Turkey',
#         'code': 'TR',
#         'codeLong': 'TUR'},
#        'region': {'city': 'Istanbul'}},
#       'timezone': {'name': 'Europe/Istanbul',
#        'offset': 10800,
#        'offsetHours': '3:00',
#        'abbr': '+03',
#        'abbrName': '',
#        'isDst': False},
#       'visible': True,
#       'website': None},
#      'destination': {'name': 'Tehran Imam Khomeini International Airport',
#       'code': {'iata': 'IKA', 'icao': 'OIIE'},
#       'position': {'latitude': 35.416111,
#        'longitude': 51.152222,
#        'altitude': 3305,
#        'country': {'id': 104, 'name': 'Iran', 'code': 'IR', 'codeLong': 'IRN'},
#        'region': {'city': 'Tehran'}},
#       'timezone': {'name': 'Asia/Tehran',
#        'offset': 12600,
#        'offsetHours': '3:30',
#        'abbr': '+0330',
#        'abbrName': '',
#        'isDst': False},
#       'visible': True,
#       'website': None}},
#     'time': {'real': {'departure': 1692000296}}},
#    {'identification': {'id': '3194ba7f', 'number': {'default': 'W5112'}},
#     'airport': {'origin': {'name': 'Tehran Imam Khomeini International Airport',
#       'code': {'iata': 'IKA', 'icao': 'OIIE'},
#       'position': {'latitude': 35.416111,
#        'longitude': 51.152222,
#        'altitude': 3305,
#        'country': {'id': 104, 'name': 'Iran', 'code': 'IR', 'codeLong': 'IRN'},
#        'region': {'city': 'Tehran'}},
#       'timezone': {'name': 'Asia/Tehran',
#        'offset': 12600,
#        'offsetHours': '3:30',
#        'abbr': '+0330',
#        'abbrName': '',
#        'isDst': False},
#       'visible': True,
#       'website': None},
#      'destination': {'name': 'Istanbul Airport',
#       'code': {'iata': 'IST', 'icao': 'LTFM'},
#       'position': {'latitude': 41.267052,
#        'longitude': 28.729757,
#        'altitude': 325,
#        'country': {'id': 228,
#         'name': 'Turkey',
#         'code': 'TR',
#         'codeLong': 'TUR'},
#        'region': {'city': 'Istanbul'}},
#       'timezone': {'name': 'Europe/Istanbul',
#        'offset': 10800,
#        'offsetHours': '3:00',
#        'abbr': '+03',
#        'abbrName': '',
#        'isDst': False},
#       'visible': True,
#       'website': None}},
#     'time': {'real': {'departure': 1691980305}}}]},
#  'ems': None,
#  'availability': ['AGE', 'MSN'],
#  'time': {'scheduled': {'departure': 1692080100, 'arrival': 1692087900},
#   'real': {'departure': 1692080595, 'arrival': None},
#   'estimated': {'departure': None, 'arrival': 1692087033},
#   'other': {'eta': 1692087033, 'updated': 1692086257},
#   'historical': {'flighttime': '6558', 'delay': '29'}},
#  'trail': [{'lat': 25.446075,
#    'lng': 55.150757,
#    'alt': 4000,
#    'spd': 222,
#    'ts': 1692086766,
#    'hd': 264},
#   {'lat': 25.446259,
#    'lng': 55.154266,
#    'alt': 4100,
#    'spd': 223,
#    'ts': 1692086763,
#    'hd': 271},
#   {'lat': 25.446152,
#    'lng': 55.157482,
#    'alt': 4200,
#    'spd': 224,
#    'ts': 1692086760,
#    'hd': 278},
#   {'lat': 25.445639,
#    'lng': 55.160797,
#    'alt': 4300,
#    'spd': 226,
#    'ts': 1692086757,
#    'hd': 285},
#   {'lat': 25.444708,
#    'lng': 55.164219,
#    'alt': 4400,
#    'spd': 226,
#    'ts': 1692086754,
#    'hd': 292},
#   {'lat': 25.440378,
#    'lng': 55.17334,
#    'alt': 4625,
#    'spd': 226,
#    'ts': 1692086745,
#    'hd': 301},
#   {'lat': 25.438656,
#    'lng': 55.176552,
#    'alt': 4675,
#    'spd': 226,
#    'ts': 1692086742,
#    'hd': 300},
#   {'lat': 25.43692,
#    'lng': 55.179699,
#    'alt': 4750,
#    'spd': 226,
#    'ts': 1692086739,
#    'hd': 300},
#   {'lat': 25.435547,
#    'lng': 55.182293,
#    'alt': 4800,
#    'spd': 226,
#    'ts': 1692086736,
#    'hd': 300},
#   {'lat': 25.433815,
#    'lng': 55.18557,
#    'alt': 4850,
#    'spd': 226,
#    'ts': 1692086733,
#    'hd': 300},
#   {'lat': 25.432343,
#    'lng': 55.188343,
#    'alt': 4925,
#    'spd': 226,
#    'ts': 1692086730,
#    'hd': 299},
#   {'lat': 25.430696,
#    'lng': 55.191582,
#    'alt': 4975,
#    'spd': 226,
#    'ts': 1692086727,
#    'hd': 299},
#   {'lat': 25.429138,
#    'lng': 55.194599,
#    'alt': 5050,
#    'spd': 224,
#    'ts': 1692086724,
#    'hd': 299},
#   {'lat': 25.427485,
#    'lng': 55.197746,
#    'alt': 5125,
#    'spd': 223,
#    'ts': 1692086721,
#    'hd': 299},
#   {'lat': 25.426025,
#    'lng': 55.200603,
#    'alt': 5200,
#    'spd': 222,
#    'ts': 1692086718,
#    'hd': 298},
#   {'lat': 25.424561,
#    'lng': 55.203655,
#    'alt': 5250,
#    'spd': 222,
#    'ts': 1692086715,
#    'hd': 294},
#   {'lat': 25.42337,
#    'lng': 55.206604,
#    'alt': 5300,
#    'spd': 222,
#    'ts': 1692086712,
#    'hd': 289},
#   {'lat': 25.422363,
#    'lng': 55.210133,
#    'alt': 5350,
#    'spd': 222,
#    'ts': 1692086709,
#    'hd': 282},
#   {'lat': 25.421804,
#    'lng': 55.213451,
#    'alt': 5425,
#    'spd': 222,
#    'ts': 1692086706,
#    'hd': 276},
#   {'lat': 25.421759,
#    'lng': 55.226925,
#    'alt': 5625,
#    'spd': 224,
#    'ts': 1692086694,
#    'hd': 267},
#   {'lat': 25.421906,
#    'lng': 55.230305,
#    'alt': 5650,
#    'spd': 225,
#    'ts': 1692086691,
#    'hd': 267},
#   {'lat': 25.422131,
#    'lng': 55.234955,
#    'alt': 5700,
#    'spd': 226,
#    'ts': 1692086687,
#    'hd': 266},
#   {'lat': 25.422272,
#    'lng': 55.237732,
#    'alt': 5725,
#    'spd': 227,
#    'ts': 1692086685,
#    'hd': 266},
#   {'lat': 25.422457,
#    'lng': 55.240707,
#    'alt': 5775,
#    'spd': 228,
#    'ts': 1692086682,
#    'hd': 265},
#   {'lat': 25.422689,
#    'lng': 55.244389,
#    'alt': 5825,
#    'spd': 228,
#    'ts': 1692086678,
#    'hd': 265},
#   {'lat': 25.422958,
#    'lng': 55.247753,
#    'alt': 5875,
#    'spd': 229,
#    'ts': 1692086676,
#    'hd': 265},
#   {'lat': 25.42337,
#    'lng': 55.252941,
#    'alt': 5900,
#    'spd': 230,
#    'ts': 1692086673,
#    'hd': 264},
#   {'lat': 25.423599,
#    'lng': 55.255329,
#    'alt': 5975,
#    'spd': 230,
#    'ts': 1692086669,
#    'hd': 263},
#   {'lat': 25.424057,
#    'lng': 55.259197,
#    'alt': 6025,
#    'spd': 230,
#    'ts': 1692086666,
#    'hd': 260},
#   {'lat': 25.424644,
#    'lng': 55.262165,
#    'alt': 6100,
#    'spd': 229,
#    'ts': 1692086663,
#    'hd': 254},
#   {'lat': 25.425669,
#    'lng': 55.265636,
#    'alt': 6150,
#    'spd': 228,
#    'ts': 1692086660,
#    'hd': 247},
#   {'lat': 25.426926,
#    'lng': 55.268642,
#    'alt': 6225,
#    'spd': 228,
#    'ts': 1692086657,
#    'hd': 241},
#   {'lat': 25.428406,
#    'lng': 55.271404,
#    'alt': 6300,
#    'spd': 228,
#    'ts': 1692086654,
#    'hd': 234},
#   {'lat': 25.430603,
#    'lng': 55.274498,
#    'alt': 6375,
#    'spd': 227,
#    'ts': 1692086651,
#    'hd': 225},
#   {'lat': 25.433258,
#    'lng': 55.277454,
#    'alt': 6425,
#    'spd': 226,
#    'ts': 1692086648,
#    'hd': 221},
#   {'lat': 25.43535,
#    'lng': 55.279213,
#    'alt': 6500,
#    'spd': 226,
#    'ts': 1692086645,
#    'hd': 214},
#   {'lat': 25.437773,
#    'lng': 55.280922,
#    'alt': 6550,
#    'spd': 226,
#    'ts': 1692086642,
#    'hd': 206},
#   {'lat': 25.440659,
#    'lng': 55.282478,
#    'alt': 6625,
#    'spd': 227,
#    'ts': 1692086639,
#    'hd': 199},
#   {'lat': 25.443649,
#    'lng': 55.283661,
#    'alt': 6675,
#    'spd': 228,
#    'ts': 1692086636,
#    'hd': 192},
#   {'lat': 25.446804,
#    'lng': 55.284447,
#    'alt': 6725,
#    'spd': 227,
#    'ts': 1692086633,
#    'hd': 186},
#   {'lat': 25.450016,
#    'lng': 55.284809,
#    'alt': 6800,
#    'spd': 228,
#    'ts': 1692086630,
#    'hd': 179},
#   {'lat': 25.453135,
#    'lng': 55.28476,
#    'alt': 6850,
#    'spd': 227,
#    'ts': 1692086627,
#    'hd': 175},
#   {'lat': 25.456068,
#    'lng': 55.284344,
#    'alt': 6925,
#    'spd': 228,
#    'ts': 1692086624,
#    'hd': 166},
#   {'lat': 25.459396,
#    'lng': 55.283459,
#    'alt': 7000,
#    'spd': 228,
#    'ts': 1692086621,
#    'hd': 159},
#   {'lat': 25.462509,
#    'lng': 55.282135,
#    'alt': 7050,
#    'spd': 228,
#    'ts': 1692086618,
#    'hd': 153},
#   {'lat': 25.465097,
#    'lng': 55.280716,
#    'alt': 7125,
#    'spd': 226,
#    'ts': 1692086615,
#    'hd': 149},
#   {'lat': 25.46817,
#    'lng': 55.278488,
#    'alt': 7175,
#    'spd': 226,
#    'ts': 1692086612,
#    'hd': 143},
#   {'lat': 25.470545,
#    'lng': 55.27626,
#    'alt': 7250,
#    'spd': 226,
#    'ts': 1692086609,
#    'hd': 136},
#   {'lat': 25.476334,
#    'lng': 55.2682,
#    'alt': 7350,
#    'spd': 224,
#    'ts': 1692086600,
#    'hd': 122},
#   {'lat': 25.484711,
#    'lng': 55.253094,
#    'alt': 7325,
#    'spd': 237,
#    'ts': 1692086585,
#    'hd': 121},
#   {'lat': 25.493866,
#    'lng': 55.236511,
#    'alt': 7325,
#    'spd': 255,
#    'ts': 1692086570,
#    'hd': 121},
#   {'lat': 25.502993,
#    'lng': 55.219978,
#    'alt': 7325,
#    'spd': 257,
#    'ts': 1692086555,
#    'hd': 121},
#   {'lat': 25.512163,
#    'lng': 55.203449,
#    'alt': 7325,
#    'spd': 255,
#    'ts': 1692086540,
#    'hd': 121},
#   {'lat': 25.521519,
#    'lng': 55.186554,
#    'alt': 7325,
#    'spd': 253,
#    'ts': 1692086525,
#    'hd': 121},
#   {'lat': 25.530924,
#    'lng': 55.169506,
#    'alt': 7375,
#    'spd': 257,
#    'ts': 1692086510,
#    'hd': 121},
#   {'lat': 25.540279,
#    'lng': 55.152611,
#    'alt': 7625,
#    'spd': 258,
#    'ts': 1692086494,
#    'hd': 121},
#   {'lat': 25.549438,
#    'lng': 55.135906,
#    'alt': 7875,
#    'spd': 260,
#    'ts': 1692086480,
#    'hd': 121},
#   {'lat': 25.558762,
#    'lng': 55.118824,
#    'alt': 8125,
#    'spd': 260,
#    'ts': 1692086465,
#    'hd': 121},
#   {'lat': 25.568481,
#    'lng': 55.101471,
#    'alt': 8350,
#    'spd': 264,
#    'ts': 1692086450,
#    'hd': 122},
#   {'lat': 25.570213,
#    'lng': 55.098457,
#    'alt': 8400,
#    'spd': 263,
#    'ts': 1692086447,
#    'hd': 122},
#   {'lat': 25.572647,
#    'lng': 55.094196,
#    'alt': 8450,
#    'spd': 264,
#    'ts': 1692086444,
#    'hd': 122},
#   {'lat': 25.574203,
#    'lng': 55.091553,
#    'alt': 8500,
#    'spd': 264,
#    'ts': 1692086441,
#    'hd': 123},
#   {'lat': 25.576309,
#    'lng': 55.087994,
#    'alt': 8550,
#    'spd': 264,
#    'ts': 1692086438,
#    'hd': 123},
#   {'lat': 25.578407,
#    'lng': 55.084568,
#    'alt': 8600,
#    'spd': 264,
#    'ts': 1692086435,
#    'hd': 123},
#   {'lat': 25.580475,
#    'lng': 55.081074,
#    'alt': 8650,
#    'spd': 264,
#    'ts': 1692086432,
#    'hd': 123},
#   {'lat': 25.582672,
#    'lng': 55.077362,
#    'alt': 8700,
#    'spd': 264,
#    'ts': 1692086429,
#    'hd': 122},
#   {'lat': 25.584457,
#    'lng': 55.074257,
#    'alt': 8750,
#    'spd': 265,
#    'ts': 1692086426,
#    'hd': 121},
#   {'lat': 25.586334,
#    'lng': 55.070698,
#    'alt': 8800,
#    'spd': 266,
#    'ts': 1692086423,
#    'hd': 116},
#   {'lat': 25.588028,
#    'lng': 55.066833,
#    'alt': 8850,
#    'spd': 265,
#    'ts': 1692086420,
#    'hd': 112},
#   {'lat': 25.589355,
#    'lng': 55.062866,
#    'alt': 8900,
#    'spd': 266,
#    'ts': 1692086417,
#    'hd': 106},
#   {'lat': 25.590179,
#    'lng': 55.059559,
#    'alt': 8950,
#    'spd': 265,
#    'ts': 1692086414,
#    'hd': 101},
#   {'lat': 25.592789,
#    'lng': 55.039471,
#    'alt': 9225,
#    'spd': 266,
#    'ts': 1692086399,
#    'hd': 96},
#   {'lat': 25.595123,
#    'lng': 55.017956,
#    'alt': 9475,
#    'spd': 268,
#    'ts': 1692086384,
#    'hd': 97},
#   {'lat': 25.597399,
#    'lng': 54.997559,
#    'alt': 9725,
#    'spd': 270,
#    'ts': 1692086369,
#    'hd': 97},
#   {'lat': 25.599747,
#    'lng': 54.976856,
#    'alt': 9975,
#    'spd': 270,
#    'ts': 1692086354,
#    'hd': 97},
#   {'lat': 25.602036,
#    'lng': 54.956867,
#    'alt': 10300,
#    'spd': 267,
#    'ts': 1692086338,
#    'hd': 97},
#   {'lat': 25.60437,
#    'lng': 54.936321,
#    'alt': 10400,
#    'spd': 271,
#    'ts': 1692086323,
#    'hd': 96},
#   {'lat': 25.606522,
#    'lng': 54.916077,
#    'alt': 10625,
#    'spd': 273,
#    'ts': 1692086308,
#    'hd': 96},
#   {'lat': 25.606989,
#    'lng': 54.911739,
#    'alt': 10675,
#    'spd': 274,
#    'ts': 1692086305,
#    'hd': 96},
#   {'lat': 25.607391,
#    'lng': 54.907429,
#    'alt': 10725,
#    'spd': 275,
#    'ts': 1692086302,
#    'hd': 95},
#   {'lat': 25.607758,
#    'lng': 54.90321,
#    'alt': 10750,
#    'spd': 276,
#    'ts': 1692086299,
#    'hd': 95},
#   {'lat': 25.60817,
#    'lng': 54.899036,
#    'alt': 10775,
#    'spd': 277,
#    'ts': 1692086296,
#    'hd': 95},
#   {'lat': 25.608572,
#    'lng': 54.894432,
#    'alt': 10825,
#    'spd': 278,
#    'ts': 1692086293,
#    'hd': 95},
#   {'lat': 25.608948,
#    'lng': 54.889984,
#    'alt': 10850,
#    'spd': 279,
#    'ts': 1692086290,
#    'hd': 95},
#   {'lat': 25.609314,
#    'lng': 54.886066,
#    'alt': 10875,
#    'spd': 281,
#    'ts': 1692086287,
#    'hd': 96},
#   {'lat': 25.609829,
#    'lng': 54.881634,
#    'alt': 10875,
#    'spd': 282,
#    'ts': 1692086284,
#    'hd': 98},
#   {'lat': 25.610367,
#    'lng': 54.87793,
#    'alt': 10900,
#    'spd': 284,
#    'ts': 1692086281,
#    'hd': 101},
#   {'lat': 25.61142,
#    'lng': 54.872997,
#    'alt': 10950,
#    'spd': 285,
#    'ts': 1692086278,
#    'hd': 106},
#   {'lat': 25.61261,
#    'lng': 54.869282,
#    'alt': 10975,
#    'spd': 286,
#    'ts': 1692086275,
#    'hd': 112},
#   {'lat': 25.614395,
#    'lng': 54.865009,
#    'alt': 11050,
#    'spd': 286,
#    'ts': 1692086272,
#    'hd': 118},
#   {'lat': 25.616253,
#    'lng': 54.861576,
#    'alt': 11100,
#    'spd': 286,
#    'ts': 1692086269,
#    'hd': 124},
#   {'lat': 25.61928,
#    'lng': 54.857018,
#    'alt': 11150,
#    'spd': 287,
#    'ts': 1692086266,
#    'hd': 130},
#   {'lat': 25.632935,
#    'lng': 54.841969,
#    'alt': 11425,
#    'spd': 288,
#    'ts': 1692086251,
#    'hd': 136},
#   {'lat': 25.647583,
#    'lng': 54.826595,
#    'alt': 11700,
#    'spd': 289,
#    'ts': 1692086236,
#    'hd': 136},
#   {'lat': 25.66214,
#    'lng': 54.811401,
#    'alt': 11925,
#    'spd': 292,
#    'ts': 1692086221,
#    'hd': 136},
#   {'lat': 25.695578,
#    'lng': 54.776173,
#    'alt': 12400,
#    'spd': 298,
#    'ts': 1692086188,
#    'hd': 136},
#   {'lat': 25.728104,
#    'lng': 54.741772,
#    'alt': 13050,
#    'spd': 299,
#    'ts': 1692086155,
#    'hd': 136},
#   {'lat': 25.762482,
#    'lng': 54.705303,
#    'alt': 13325,
#    'spd': 316,
#    'ts': 1692086122,
#    'hd': 136},
#   {'lat': 25.765274,
#    'lng': 54.702404,
#    'alt': 13325,
#    'spd': 319,
#    'ts': 1692086119,
#    'hd': 137},
#   {'lat': 25.769028,
#    'lng': 54.698536,
#    'alt': 13325,
#    'spd': 322,
#    'ts': 1692086116,
#    'hd': 137},
#   {'lat': 25.772232,
#    'lng': 54.695282,
#    'alt': 13325,
#    'spd': 322,
#    'ts': 1692086113,
#    'hd': 137},
#   {'lat': 25.775116,
#    'lng': 54.692383,
#    'alt': 13325,
#    'spd': 322,
#    'ts': 1692086110,
#    'hd': 138},
#   {'lat': 25.778778,
#    'lng': 54.68877,
#    'alt': 13350,
#    'spd': 321,
#    'ts': 1692086107,
#    'hd': 138},
#   {'lat': 25.786194,
#    'lng': 54.681347,
#    'alt': 13350,
#    'spd': 322,
#    'ts': 1692086101,
#    'hd': 136},
#   {'lat': 25.788345,
#    'lng': 54.679058,
#    'alt': 13375,
#    'spd': 322,
#    'ts': 1692086098,
#    'hd': 134},
#   {'lat': 25.791962,
#    'lng': 54.674835,
#    'alt': 13375,
#    'spd': 324,
#    'ts': 1692086095,
#    'hd': 129},
#   {'lat': 25.794342,
#    'lng': 54.671528,
#    'alt': 13400,
#    'spd': 324,
#    'ts': 1692086092,
#    'hd': 124},
#   {'lat': 25.80867,
#    'lng': 54.634449,
#    'alt': 13950,
#    'spd': 326,
#    'ts': 1692086068,
#    'hd': 109},
#   {'lat': 25.825333,
#    'lng': 54.581806,
#    'alt': 14650,
#    'spd': 330,
#    'ts': 1692086035,
#    'hd': 109},
#   {'lat': 25.841812,
#    'lng': 54.529396,
#    'alt': 15475,
#    'spd': 329,
#    'ts': 1692086002,
#    'hd': 109},
#   {'lat': 25.85865,
#    'lng': 54.476234,
#    'alt': 16200,
#    'spd': 335,
#    'ts': 1692085969,
#    'hd': 109},
#   {'lat': 25.875549,
#    'lng': 54.422203,
#    'alt': 17050,
#    'spd': 336,
#    'ts': 1692085935,
#    'hd': 109},
#   {'lat': 25.892715,
#    'lng': 54.367607,
#    'alt': 17750,
#    'spd': 342,
#    'ts': 1692085902,
#    'hd': 108},
#   {'lat': 25.909973,
#    'lng': 54.312103,
#    'alt': 18500,
#    'spd': 348,
#    'ts': 1692085869,
#    'hd': 109},
#   {'lat': 25.931784,
#    'lng': 54.258465,
#    'alt': 19325,
#    'spd': 352,
#    'ts': 1692085836,
#    'hd': 117},
#   {'lat': 25.955292,
#    'lng': 54.209446,
#    'alt': 19700,
#    'spd': 369,
#    'ts': 1692085806,
#    'hd': 117},
#   {'lat': 25.982346,
#    'lng': 54.152802,
#    'alt': 20350,
#    'spd': 381,
#    'ts': 1692085773,
#    'hd': 117},
#   {'lat': 26.010269,
#    'lng': 54.09388,
#    'alt': 21125,
#    'spd': 390,
#    'ts': 1692085741,
#    'hd': 117},
#   {'lat': 26.03627,
#    'lng': 54.041489,
#    'alt': 22025,
#    'spd': 396,
#    'ts': 1692085710,
#    'hd': 122},
#   {'lat': 26.071627,
#    'lng': 53.986816,
#    'alt': 22850,
#    'spd': 406,
#    'ts': 1692085677,
#    'hd': 129},
#   {'lat': 26.112734,
#    'lng': 53.937748,
#    'alt': 23425,
#    'spd': 426,
#    'ts': 1692085646,
#    'hd': 137},
#   {'lat': 26.164902,
#    'lng': 53.890842,
#    'alt': 24450,
#    'spd': 435,
#    'ts': 1692085613,
#    'hd': 145},
#   {'lat': 26.21814,
#    'lng': 53.850731,
#    'alt': 25025,
#    'spd': 431,
#    'ts': 1692085580,
#    'hd': 145},
#   {'lat': 26.273712,
#    'lng': 53.808964,
#    'alt': 25000,
#    'spd': 431,
#    'ts': 1692085547,
#    'hd': 145},
#   {'lat': 26.326767,
#    'lng': 53.768902,
#    'alt': 25000,
#    'spd': 429,
#    'ts': 1692085514,
#    'hd': 145},
#   {'lat': 26.382177,
#    'lng': 53.727158,
#    'alt': 25575,
#    'spd': 431,
#    'ts': 1692085481,
#    'hd': 145},
#   {'lat': 26.435989,
#    'lng': 53.686298,
#    'alt': 26600,
#    'spd': 440,
#    'ts': 1692085448,
#    'hd': 145},
#   {'lat': 26.487665,
#    'lng': 53.64682,
#    'alt': 27575,
#    'spd': 448,
#    'ts': 1692085418,
#    'hd': 145},
#   {'lat': 26.546135,
#    'lng': 53.603191,
#    'alt': 28700,
#    'spd': 455,
#    'ts': 1692085384,
#    'hd': 143},
#   {'lat': 26.601746,
#    'lng': 53.553581,
#    'alt': 29800,
#    'spd': 461,
#    'ts': 1692085351,
#    'hd': 139},
#   {'lat': 26.662628,
#    'lng': 53.496216,
#    'alt': 31025,
#    'spd': 470,
#    'ts': 1692085314,
#    'hd': 139},
#   {'lat': 26.714514,
#    'lng': 53.446903,
#    'alt': 32075,
#    'spd': 478,
#    'ts': 1692085283,
#    'hd': 140},
#   {'lat': 26.779221,
#    'lng': 53.394768,
#    'alt': 33400,
#    'spd': 474,
#    'ts': 1692085247,
#    'hd': 148},
#   {'lat': 26.84379,
#    'lng': 53.355736,
#    'alt': 33950,
#    'spd': 472,
#    'ts': 1692085214,
#    'hd': 155},
#   {'lat': 26.907486,
#    'lng': 53.327583,
#    'alt': 34475,
#    'spd': 466,
#    'ts': 1692085183,
#    'hd': 162},
#   {'lat': 26.976044,
#    'lng': 53.305717,
#    'alt': 34975,
#    'spd': 464,
#    'ts': 1692085150,
#    'hd': 164},
#   {'lat': 27.045593,
#    'lng': 53.284485,
#    'alt': 35000,
#    'spd': 464,
#    'ts': 1692085115,
#    'hd': 164},
#   {'lat': 27.114304,
#    'lng': 53.263409,
#    'alt': 35000,
#    'spd': 464,
#    'ts': 1692085082,
#    'hd': 164},
#   {'lat': 27.180084,
#    'lng': 53.243114,
#    'alt': 35000,
#    'spd': 467,
#    'ts': 1692085051,
#    'hd': 164},
#   {'lat': 27.247723,
#    'lng': 53.221893,
#    'alt': 35000,
#    'spd': 466,
#    'ts': 1692085018,
#    'hd': 164},
#   {'lat': 27.316668,
#    'lng': 53.199921,
#    'alt': 35000,
#    'spd': 468,
#    'ts': 1692084985,
#    'hd': 164},
#   {'lat': 27.38942,
#    'lng': 53.179581,
#    'alt': 35000,
#    'spd': 468,
#    'ts': 1692084951,
#    'hd': 166},
#   {'lat': 27.459396,
#    'lng': 53.161098,
#    'alt': 35000,
#    'spd': 467,
#    'ts': 1692084918,
#    'hd': 166},
#   {'lat': 27.528481,
#    'lng': 53.142822,
#    'alt': 35000,
#    'spd': 468,
#    'ts': 1692084885,
#    'hd': 166},
#   {'lat': 27.596725,
#    'lng': 53.12476,
#    'alt': 35000,
#    'spd': 468,
#    'ts': 1692084852,
#    'hd': 166},
#   {'lat': 27.671173,
#    'lng': 53.105007,
#    'alt': 35000,
#    'spd': 469,
#    'ts': 1692084817,
#    'hd': 166},
#   {'lat': 27.754715,
#    'lng': 53.082775,
#    'alt': 35000,
#    'spd': 470,
#    'ts': 1692084778,
#    'hd': 166},
#   {'lat': 27.82988,
#    'lng': 53.062824,
#    'alt': 35000,
#    'spd': 468,
#    'ts': 1692084742,
#    'hd': 166},
#   {'lat': 27.924173,
#    'lng': 53.037663,
#    'alt': 35000,
#    'spd': 468,
#    'ts': 1692084698,
#    'hd': 166},
#   {'lat': 27.994001,
#    'lng': 53.018997,
#    'alt': 35000,
#    'spd': 472,
#    'ts': 1692084665,
#    'hd': 166},
#   {'lat': 28.066177,
#    'lng': 52.999737,
#    'alt': 35000,
#    'spd': 474,
#    'ts': 1692084632,
#    'hd': 166},
#   {'lat': 28.189848,
#    'lng': 52.966648,
#    'alt': 35000,
#    'spd': 476,
#    'ts': 1692084573,
#    'hd': 166},
#   {'lat': 28.211655,
#    'lng': 52.960808,
#    'alt': 35000,
#    'spd': 476,
#    'ts': 1692084563,
#    'hd': 166},
#   {'lat': 28.281509,
#    'lng': 52.942165,
#    'alt': 35000,
#    'spd': 477,
#    'ts': 1692084530,
#    'hd': 166},
#   {'lat': 28.350586,
#    'lng': 52.923729,
#    'alt': 35000,
#    'spd': 476,
#    'ts': 1692084498,
#    'hd': 166},
#   {'lat': 28.429592,
#    'lng': 52.90197,
#    'alt': 35000,
#    'spd': 474,
#    'ts': 1692084463,
#    'hd': 166},
#   {'lat': 28.518133,
#    'lng': 52.877251,
#    'alt': 35000,
#    'spd': 471,
#    'ts': 1692084420,
#    'hd': 166},
#   {'lat': 28.591732,
#    'lng': 52.856625,
#    'alt': 35000,
#    'spd': 473,
#    'ts': 1692084385,
#    'hd': 166},
#   {'lat': 28.65374,
#    'lng': 52.83923,
#    'alt': 35000,
#    'spd': 474,
#    'ts': 1692084356,
#    'hd': 166},
#   {'lat': 28.721706,
#    'lng': 52.820164,
#    'alt': 35000,
#    'spd': 474,
#    'ts': 1692084324,
#    'hd': 166},
#   {'lat': 28.795486,
#    'lng': 52.799446,
#    'alt': 35000,
#    'spd': 474,
#    'ts': 1692084290,
#    'hd': 166},
#   {'lat': 28.86248,
#    'lng': 52.780636,
#    'alt': 35000,
#    'spd': 477,
#    'ts': 1692084258,
#    'hd': 166},
#   {'lat': 28.929562,
#    'lng': 52.761734,
#    'alt': 35000,
#    'spd': 476,
#    'ts': 1692084227,
#    'hd': 166},
#   {'lat': 28.99942,
#    'lng': 52.742035,
#    'alt': 35000,
#    'spd': 476,
#    'ts': 1692084194,
#    'hd': 166},
#   {'lat': 29.062683,
#    'lng': 52.724182,
#    'alt': 35000,
#    'spd': 476,
#    'ts': 1692084165,
#    'hd': 165},
#   {'lat': 29.130482,
#    'lng': 52.705025,
#    'alt': 35000,
#    'spd': 478,
#    'ts': 1692084133,
#    'hd': 165},
#   {'lat': 29.197769,
#    'lng': 52.685993,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692084102,
#    'hd': 165},
#   {'lat': 29.265297,
#    'lng': 52.66684,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692084071,
#    'hd': 165},
#   {'lat': 29.333267,
#    'lng': 52.647488,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692084039,
#    'hd': 165},
#   {'lat': 29.402252,
#    'lng': 52.627682,
#    'alt': 35000,
#    'spd': 480,
#    'ts': 1692084007,
#    'hd': 165},
#   {'lat': 29.470596,
#    'lng': 52.607925,
#    'alt': 35000,
#    'spd': 481,
#    'ts': 1692083975,
#    'hd': 166},
#   {'lat': 29.538803,
#    'lng': 52.588699,
#    'alt': 35000,
#    'spd': 480,
#    'ts': 1692083944,
#    'hd': 163},
#   {'lat': 29.60713,
#    'lng': 52.563278,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083912,
#    'hd': 161},
#   {'lat': 29.673653,
#    'lng': 52.538021,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083880,
#    'hd': 161},
#   {'lat': 29.746674,
#    'lng': 52.510212,
#    'alt': 35000,
#    'spd': 478,
#    'ts': 1692083845,
#    'hd': 161},
#   {'lat': 29.812958,
#    'lng': 52.484962,
#    'alt': 35000,
#    'spd': 477,
#    'ts': 1692083814,
#    'hd': 161},
#   {'lat': 29.879333,
#    'lng': 52.45961,
#    'alt': 35000,
#    'spd': 477,
#    'ts': 1692083782,
#    'hd': 161},
#   {'lat': 29.953583,
#    'lng': 52.431175,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083747,
#    'hd': 161},
#   {'lat': 30.020096,
#    'lng': 52.40572,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083715,
#    'hd': 161},
#   {'lat': 30.087387,
#    'lng': 52.379906,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083684,
#    'hd': 161},
#   {'lat': 30.157242,
#    'lng': 52.353031,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083650,
#    'hd': 161},
#   {'lat': 30.222551,
#    'lng': 52.327934,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083619,
#    'hd': 161},
#   {'lat': 30.289627,
#    'lng': 52.302086,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083588,
#    'hd': 161},
#   {'lat': 30.355774,
#    'lng': 52.276558,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083556,
#    'hd': 161},
#   {'lat': 30.423615,
#    'lng': 52.250332,
#    'alt': 35000,
#    'spd': 478,
#    'ts': 1692083524,
#    'hd': 161},
#   {'lat': 30.489441,
#    'lng': 52.224857,
#    'alt': 35000,
#    'spd': 477,
#    'ts': 1692083493,
#    'hd': 161},
#   {'lat': 30.616522,
#    'lng': 52.17561,
#    'alt': 35000,
#    'spd': 476,
#    'ts': 1692083433,
#    'hd': 161},
#   {'lat': 30.65332,
#    'lng': 52.161255,
#    'alt': 35000,
#    'spd': 477,
#    'ts': 1692083415,
#    'hd': 161},
#   {'lat': 30.718752,
#    'lng': 52.135674,
#    'alt': 35000,
#    'spd': 478,
#    'ts': 1692083383,
#    'hd': 161},
#   {'lat': 30.785833,
#    'lng': 52.109474,
#    'alt': 35000,
#    'spd': 478,
#    'ts': 1692083352,
#    'hd': 161},
#   {'lat': 30.850121,
#    'lng': 52.084312,
#    'alt': 35000,
#    'spd': 478,
#    'ts': 1692083321,
#    'hd': 161},
#   {'lat': 30.916784,
#    'lng': 52.058167,
#    'alt': 35000,
#    'spd': 479,
#    'ts': 1692083289,
#    'hd': 161},
#   {'lat': 30.987917,
#    'lng': 52.030205,
#    'alt': 34850,
#    'spd': 479,
#    'ts': 1692083255,
#    'hd': 161},
#   {'lat': 31.052856,
#    'lng': 52.0047,
#    'alt': 34600,
#    'spd': 480,
#    'ts': 1692083224,
#    'hd': 161},
#   {'lat': 31.119844,
#    'lng': 51.978294,
#    'alt': 34325,
#    'spd': 481,
#    'ts': 1692083193,
#    'hd': 161},
#   {'lat': 31.184505,
#    'lng': 51.952751,
#    'alt': 34075,
#    'spd': 483,
#    'ts': 1692083162,
#    'hd': 161},
#   {'lat': 31.251076,
#    'lng': 51.926495,
#    'alt': 33800,
#    'spd': 484,
#    'ts': 1692083131,
#    'hd': 161},
#   {'lat': 31.31662,
#    'lng': 51.900543,
#    'alt': 33525,
#    'spd': 485,
#    'ts': 1692083100,
#    'hd': 161},
#   {'lat': 31.383797,
#    'lng': 51.873981,
#    'alt': 33275,
#    'spd': 487,
#    'ts': 1692083068,
#    'hd': 161},
#   {'lat': 31.450365,
#    'lng': 51.847504,
#    'alt': 33025,
#    'spd': 487,
#    'ts': 1692083037,
#    'hd': 161},
#   {'lat': 31.5168,
#    'lng': 51.82111,
#    'alt': 33000,
#    'spd': 482,
#    'ts': 1692083006,
#    'hd': 161},
#   {'lat': 31.583134,
#    'lng': 51.794716,
#    'alt': 33000,
#    'spd': 482,
#    'ts': 1692082975,
#    'hd': 161},
#   {'lat': 31.649597,
#    'lng': 51.768169,
#    'alt': 32775,
#    'spd': 482,
#    'ts': 1692082944,
#    'hd': 161},
#   {'lat': 31.716522,
#    'lng': 51.741459,
#    'alt': 32500,
#    'spd': 482,
#    'ts': 1692082912,
#    'hd': 161},
#   {'lat': 31.786798,
#    'lng': 51.713432,
#    'alt': 32225,
#    'spd': 483,
#    'ts': 1692082879,
#    'hd': 161},
#   {'lat': 31.852903,
#    'lng': 51.686974,
#    'alt': 31950,
#    'spd': 483,
#    'ts': 1692082847,
#    'hd': 161},
#   {'lat': 31.919769,
#    'lng': 51.66024,
#    'alt': 31675,
#    'spd': 484,
#    'ts': 1692082816,
#    'hd': 161},
#   {'lat': 31.985344,
#    'lng': 51.633949,
#    'alt': 31425,
#    'spd': 484,
#    'ts': 1692082785,
#    'hd': 161},
#   {'lat': 32.052521,
#    'lng': 51.606903,
#    'alt': 31150,
#    'spd': 484,
#    'ts': 1692082753,
#    'hd': 161},
#   {'lat': 32.118996,
#    'lng': 51.580193,
#    'alt': 30900,
#    'spd': 484,
#    'ts': 1692082722,
#    'hd': 161},
#   {'lat': 32.184769,
#    'lng': 51.553673,
#    'alt': 30625,
#    'spd': 484,
#    'ts': 1692082691,
#    'hd': 161},
#   {'lat': 32.250553,
#    'lng': 51.527111,
#    'alt': 30500,
#    'spd': 481,
#    'ts': 1692082660,
#    'hd': 160},
#   {'lat': 32.315872,
#    'lng': 51.500774,
#    'alt': 30425,
#    'spd': 475,
#    'ts': 1692082629,
#    'hd': 161},
#   {'lat': 32.380573,
#    'lng': 51.47459,
#    'alt': 30325,
#    'spd': 469,
#    'ts': 1692082598,
#    'hd': 160},
#   {'lat': 32.445095,
#    'lng': 51.448414,
#    'alt': 30125,
#    'spd': 466,
#    'ts': 1692082566,
#    'hd': 160},
#   {'lat': 32.508545,
#    'lng': 51.422688,
#    'alt': 29800,
#    'spd': 465,
#    'ts': 1692082535,
#    'hd': 160},
#   {'lat': 32.572266,
#    'lng': 51.396736,
#    'alt': 29550,
#    'spd': 463,
#    'ts': 1692082504,
#    'hd': 160},
#   {'lat': 32.634018,
#    'lng': 51.371632,
#    'alt': 29275,
#    'spd': 460,
#    'ts': 1692082473,
#    'hd': 160},
#   {'lat': 32.697502,
#    'lng': 51.345669,
#    'alt': 28950,
#    'spd': 459,
#    'ts': 1692082441,
#    'hd': 160},
#   {'lat': 32.759399,
#    'lng': 51.320381,
#    'alt': 28650,
#    'spd': 456,
#    'ts': 1692082411,
#    'hd': 160},
#   {'lat': 32.821335,
#    'lng': 51.295055,
#    'alt': 28300,
#    'spd': 456,
#    'ts': 1692082380,
#    'hd': 160},
#   {'lat': 32.883057,
#    'lng': 51.269829,
#    'alt': 28050,
#    'spd': 451,
#    'ts': 1692082349,
#    'hd': 160},
#   {'lat': 32.945297,
#    'lng': 51.244301,
#    'alt': 27675,
#    'spd': 449,
#    'ts': 1692082317,
#    'hd': 160},
#   {'lat': 33.006226,
#    'lng': 51.21925,
#    'alt': 27225,
#    'spd': 450,
#    'ts': 1692082286,
#    'hd': 160},
#   {'lat': 33.067566,
#    'lng': 51.194092,
#    'alt': 26825,
#    'spd': 448,
#    'ts': 1692082255,
#    'hd': 160},
#   {'lat': 33.13216,
#    'lng': 51.167477,
#    'alt': 26425,
#    'spd': 447,
#    'ts': 1692082222,
#    'hd': 160},
#   {'lat': 33.226055,
#    'lng': 51.128746,
#    'alt': 25875,
#    'spd': 443,
#    'ts': 1692082174,
#    'hd': 160},
#   {'lat': 33.291824,
#    'lng': 51.101532,
#    'alt': 25550,
#    'spd': 438,
#    'ts': 1692082140,
#    'hd': 160},
#   {'lat': 33.36026,
#    'lng': 51.073189,
#    'alt': 25175,
#    'spd': 430,
#    'ts': 1692082104,
#    'hd': 160},
#   {'lat': 33.418407,
#    'lng': 51.049095,
#    'alt': 24950,
#    'spd': 424,
#    'ts': 1692082073,
#    'hd': 160},
#   {'lat': 33.478554,
#    'lng': 51.024094,
#    'alt': 24500,
#    'spd': 422,
#    'ts': 1692082041,
#    'hd': 160},
#   {'lat': 33.537769,
#    'lng': 50.999489,
#    'alt': 24100,
#    'spd': 419,
#    'ts': 1692082009,
#    'hd': 160},
#   {'lat': 33.596283,
#    'lng': 50.975105,
#    'alt': 23650,
#    'spd': 417,
#    'ts': 1692081977,
#    'hd': 160},
#   {'lat': 33.656059,
#    'lng': 50.950127,
#    'alt': 23175,
#    'spd': 416,
#    'ts': 1692081944,
#    'hd': 160},
#   {'lat': 33.743866,
#    'lng': 50.913448,
#    'alt': 22650,
#    'spd': 412,
#    'ts': 1692081895,
#    'hd': 160},
#   {'lat': 33.799255,
#    'lng': 50.890186,
#    'alt': 22300,
#    'spd': 408,
#    'ts': 1692081864,
#    'hd': 160},
#   {'lat': 33.854004,
#    'lng': 50.86726,
#    'alt': 21950,
#    'spd': 407,
#    'ts': 1692081834,
#    'hd': 160},
#   {'lat': 33.916611,
#    'lng': 50.840893,
#    'alt': 21500,
#    'spd': 405,
#    'ts': 1692081798,
#    'hd': 160},
#   {'lat': 33.972847,
#    'lng': 50.817204,
#    'alt': 20775,
#    'spd': 413,
#    'ts': 1692081767,
#    'hd': 160},
#   {'lat': 34.028091,
#    'lng': 50.793941,
#    'alt': 20475,
#    'spd': 410,
#    'ts': 1692081736,
#    'hd': 160},
#   {'lat': 34.082748,
#    'lng': 50.770905,
#    'alt': 19825,
#    'spd': 416,
#    'ts': 1692081706,
#    'hd': 160},
#   {'lat': 34.139969,
#    'lng': 50.746689,
#    'alt': 19425,
#    'spd': 415,
#    'ts': 1692081675,
#    'hd': 160},
#   {'lat': 34.200996,
#    'lng': 50.720844,
#    'alt': 19025,
#    'spd': 414,
#    'ts': 1692081641,
#    'hd': 160},
#   {'lat': 34.256058,
#    'lng': 50.697533,
#    'alt': 18625,
#    'spd': 413,
#    'ts': 1692081610,
#    'hd': 160},
#   {'lat': 34.312866,
#    'lng': 50.673431,
#    'alt': 18250,
#    'spd': 409,
#    'ts': 1692081579,
#    'hd': 160},
#   {'lat': 34.367424,
#    'lng': 50.650234,
#    'alt': 17850,
#    'spd': 408,
#    'ts': 1692081549,
#    'hd': 160},
#   {'lat': 34.426987,
#    'lng': 50.624889,
#    'alt': 17150,
#    'spd': 413,
#    'ts': 1692081515,
#    'hd': 160},
#   {'lat': 34.482193,
#    'lng': 50.601345,
#    'alt': 16825,
#    'spd': 408,
#    'ts': 1692081484,
#    'hd': 160},
#   {'lat': 34.537491,
#    'lng': 50.577805,
#    'alt': 16500,
#    'spd': 402,
#    'ts': 1692081453,
#    'hd': 160},
#   {'lat': 34.594849,
#    'lng': 50.553421,
#    'alt': 16125,
#    'spd': 397,
#    'ts': 1692081420,
#    'hd': 160},
#   {'lat': 34.647713,
#    'lng': 50.530701,
#    'alt': 15675,
#    'spd': 394,
#    'ts': 1692081390,
#    'hd': 160},
#   {'lat': 34.654091,
#    'lng': 50.527897,
#    'alt': 15625,
#    'spd': 394,
#    'ts': 1692081386,
#    'hd': 159},
#   {'lat': 34.658478,
#    'lng': 50.525898,
#    'alt': 15600,
#    'spd': 394,
#    'ts': 1692081384,
#    'hd': 159},
#   {'lat': 34.664063,
#    'lng': 50.523434,
#    'alt': 15550,
#    'spd': 393,
#    'ts': 1692081381,
#    'hd': 159},
#   {'lat': 34.66951,
#    'lng': 50.520966,
#    'alt': 15525,
#    'spd': 391,
#    'ts': 1692081377,
#    'hd': 159},
#   {'lat': 34.674133,
#    'lng': 50.518948,
#    'alt': 15500,
#    'spd': 390,
#    'ts': 1692081374,
#    'hd': 160},
#   {'lat': 34.679993,
#    'lng': 50.516426,
#    'alt': 15475,
#    'spd': 390,
#    'ts': 1692081371,
#    'hd': 161},
#   {'lat': 34.685932,
#    'lng': 50.514164,
#    'alt': 15450,
#    'spd': 390,
#    'ts': 1692081368,
#    'hd': 164},
#   {'lat': 34.692581,
#    'lng': 50.512112,
#    'alt': 15425,
#    'spd': 390,
#    'ts': 1692081364,
#    'hd': 168},
#   {'lat': 34.696964,
#    'lng': 50.511074,
#    'alt': 15375,
#    'spd': 390,
#    'ts': 1692081361,
#    'hd': 171},
#   {'lat': 34.701714,
#    'lng': 50.510159,
#    'alt': 15350,
#    'spd': 390,
#    'ts': 1692081359,
#    'hd': 172},
#   {'lat': 34.707718,
#    'lng': 50.509415,
#    'alt': 15300,
#    'spd': 390,
#    'ts': 1692081355,
#    'hd': 176},
#   {'lat': 34.713867,
#    'lng': 50.509026,
#    'alt': 15225,
#    'spd': 392,
#    'ts': 1692081352,
#    'hd': 179},
#   {'lat': 34.719772,
#    'lng': 50.509083,
#    'alt': 15175,
#    'spd': 392,
#    'ts': 1692081349,
#    'hd': 182},
#   {'lat': 34.726273,
#    'lng': 50.509644,
#    'alt': 15150,
#    'spd': 393,
#    'ts': 1692081346,
#    'hd': 186},
#   {'lat': 34.730854,
#    'lng': 50.510387,
#    'alt': 15100,
#    'spd': 393,
#    'ts': 1692081342,
#    'hd': 189},
#   {'lat': 34.779968,
#    'lng': 50.529263,
#    'alt': 14650,
#    'spd': 392,
#    'ts': 1692081314,
#    'hd': 199},
#   {'lat': 34.832993,
#    'lng': 50.552502,
#    'alt': 14100,
#    'spd': 390,
#    'ts': 1692081283,
#    'hd': 199},
#   {'lat': 34.885483,
#    'lng': 50.575562,
#    'alt': 13500,
#    'spd': 390,
#    'ts': 1692081252,
#    'hd': 199},
#   {'lat': 34.937454,
#    'lng': 50.598392,
#    'alt': 12875,
#    'spd': 390,
#    'ts': 1692081222,
#    'hd': 199},
#   {'lat': 34.991131,
#    'lng': 50.622025,
#    'alt': 12075,
#    'spd': 394,
#    'ts': 1692081190,
#    'hd': 199},
#   {'lat': 35.012589,
#    'lng': 50.631466,
#    'alt': 11850,
#    'spd': 392,
#    'ts': 1692081178,
#    'hd': 199},
#   {'lat': 35.038612,
#    'lng': 50.64291,
#    'alt': 11675,
#    'spd': 386,
#    'ts': 1692081163,
#    'hd': 199},
#   {'lat': 35.064358,
#    'lng': 50.65424,
#    'alt': 11575,
#    'spd': 377,
#    'ts': 1692081147,
#    'hd': 199},
#   {'lat': 35.090469,
#    'lng': 50.665749,
#    'alt': 11475,
#    'spd': 367,
#    'ts': 1692081132,
#    'hd': 199},
#   {'lat': 35.114307,
#    'lng': 50.67627,
#    'alt': 11300,
#    'spd': 360,
#    'ts': 1692081116,
#    'hd': 199},
#   {'lat': 35.133087,
#    'lng': 50.684586,
#    'alt': 11100,
#    'spd': 356,
#    'ts': 1692081104,
#    'hd': 200},
#   {'lat': 35.157181,
#    'lng': 50.69521,
#    'alt': 10800,
#    'spd': 351,
#    'ts': 1692081088,
#    'hd': 200},
#   {'lat': 35.177433,
#    'lng': 50.70425,
#    'alt': 10675,
#    'spd': 345,
#    'ts': 1692081076,
#    'hd': 200},
#   {'lat': 35.19931,
#    'lng': 50.714149,
#    'alt': 10550,
#    'spd': 334,
#    'ts': 1692081060,
#    'hd': 200},
#   {'lat': 35.218678,
#    'lng': 50.723076,
#    'alt': 10450,
#    'spd': 324,
#    'ts': 1692081047,
#    'hd': 200},
#   {'lat': 35.2397,
#    'lng': 50.732861,
#    'alt': 10325,
#    'spd': 311,
#    'ts': 1692081032,
#    'hd': 200},
#   {'lat': 35.257175,
#    'lng': 50.740826,
#    'alt': 10225,
#    'spd': 300,
#    'ts': 1692081018,
#    'hd': 199},
#   {'lat': 35.260761,
#    'lng': 50.742458,
#    'alt': 10200,
#    'spd': 299,
#    'ts': 1692081016,
#    'hd': 199},
#   {'lat': 35.264557,
#    'lng': 50.744076,
#    'alt': 10150,
#    'spd': 297,
#    'ts': 1692081013,
#    'hd': 199},
#   {'lat': 35.269547,
#    'lng': 50.746193,
#    'alt': 10075,
#    'spd': 296,
#    'ts': 1692081009,
#    'hd': 198},
#   {'lat': 35.273209,
#    'lng': 50.747738,
#    'alt': 10000,
#    'spd': 295,
#    'ts': 1692081006,
#    'hd': 198},
#   {'lat': 35.2771,
#    'lng': 50.749355,
#    'alt': 9925,
#    'spd': 295,
#    'ts': 1692081003,
#    'hd': 198},
#   {'lat': 35.283012,
#    'lng': 50.751812,
#    'alt': 9850,
#    'spd': 294,
#    'ts': 1692081000,
#    'hd': 199},
#   {'lat': 35.284267,
#    'lng': 50.752396,
#    'alt': 9800,
#    'spd': 294,
#    'ts': 1692080998,
#    'hd': 204},
#   {'lat': 35.28923,
#    'lng': 50.755062,
#    'alt': 9675,
#    'spd': 295,
#    'ts': 1692080995,
#    'hd': 207},
#   {'lat': 35.29274,
#    'lng': 50.75742,
#    'alt': 9625,
#    'spd': 294,
#    'ts': 1692080991,
#    'hd': 211},
#   {'lat': 35.295952,
#    'lng': 50.759933,
#    'alt': 9550,
#    'spd': 294,
#    'ts': 1692080988,
#    'hd': 216},
#   {'lat': 35.299259,
#    'lng': 50.763031,
#    'alt': 9450,
#    'spd': 294,
#    'ts': 1692080985,
#    'hd': 221},
#   {'lat': 35.301773,
#    'lng': 50.765762,
#    'alt': 9375,
#    'spd': 294,
#    'ts': 1692080982,
#    'hd': 225},
#   {'lat': 35.310337,
#    'lng': 50.778282,
#    'alt': 9075,
#    'spd': 295,
#    'ts': 1692080973,
#    'hd': 234},
#   {'lat': 35.321976,
#    'lng': 50.798679,
#    'alt': 8775,
#    'spd': 289,
#    'ts': 1692080958,
#    'hd': 235},
#   {'lat': 35.332729,
#    'lng': 50.817612,
#    'alt': 8450,
#    'spd': 286,
#    'ts': 1692080944,
#    'hd': 235},
#   {'lat': 35.344181,
#    'lng': 50.837715,
#    'alt': 7975,
#    'spd': 287,
#    'ts': 1692080928,
#    'hd': 235},
#   {'lat': 35.356018,
#    'lng': 50.858574,
#    'alt': 7650,
#    'spd': 280,
#    'ts': 1692080913,
#    'hd': 235},
#   {'lat': 35.364578,
#    'lng': 50.87368,
#    'alt': 7425,
#    'spd': 275,
#    'ts': 1692080901,
#    'hd': 235},
#   {'lat': 35.375835,
#    'lng': 50.89352,
#    'alt': 7200,
#    'spd': 264,
#    'ts': 1692080886,
#    'hd': 234},
#   {'lat': 35.384262,
#    'lng': 50.908298,
#    'alt': 7075,
#    'spd': 252,
#    'ts': 1692080873,
#    'hd': 234},
#   {'lat': 35.394646,
#    'lng': 50.926247,
#    'alt': 6950,
#    'spd': 240,
#    'ts': 1692080858,
#    'hd': 234},
#   {'lat': 35.402699,
#    'lng': 50.940155,
#    'alt': 6825,
#    'spd': 225,
#    'ts': 1692080845,
#    'hd': 234},
#   {'lat': 35.411774,
#    'lng': 50.955757,
#    'alt': 6750,
#    'spd': 212,
#    'ts': 1692080829,
#    'hd': 234},
#   {'lat': 35.420654,
#    'lng': 50.971012,
#    'alt': 6625,
#    'spd': 200,
#    'ts': 1692080814,
#    'hd': 234},
#   {'lat': 35.428391,
#    'lng': 50.984516,
#    'alt': 6500,
#    'spd': 186,
#    'ts': 1692080798,
#    'hd': 235},
#   {'lat': 35.436028,
#    'lng': 50.997833,
#    'alt': 6400,
#    'spd': 172,
#    'ts': 1692080782,
#    'hd': 234},
#   {'lat': 35.437454,
#    'lng': 51.000309,
#    'alt': 6375,
#    'spd': 172,
#    'ts': 1692080780,
#    'hd': 234},
#   {'lat': 35.439011,
#    'lng': 51.002941,
#    'alt': 6350,
#    'spd': 169,
#    'ts': 1692080777,
#    'hd': 234},
#   {'lat': 35.440125,
#    'lng': 51.004845,
#    'alt': 6300,
#    'spd': 168,
#    'ts': 1692080773,
#    'hd': 234},
#   {'lat': 35.441528,
#    'lng': 51.00729,
#    'alt': 6275,
#    'spd': 167,
#    'ts': 1692080771,
#    'hd': 234},
#   {'lat': 35.443058,
#    'lng': 51.00993,
#    'alt': 6200,
#    'spd': 167,
#    'ts': 1692080767,
#    'hd': 234},
#   {'lat': 35.444641,
#    'lng': 51.012669,
#    'alt': 6100,
#    'spd': 167,
#    'ts': 1692080764,
#    'hd': 235},
#   {'lat': 35.446457,
#    'lng': 51.015892,
#    'alt': 6000,
#    'spd': 167,
#    'ts': 1692080760,
#    'hd': 237},
#   {'lat': 35.447247,
#    'lng': 51.017467,
#    'alt': 5925,
#    'spd': 167,
#    'ts': 1692080757,
#    'hd': 240},
#   {'lat': 35.448273,
#    'lng': 51.019691,
#    'alt': 5850,
#    'spd': 167,
#    'ts': 1692080755,
#    'hd': 244},
#   {'lat': 35.449295,
#    'lng': 51.022671,
#    'alt': 5750,
#    'spd': 168,
#    'ts': 1692080751,
#    'hd': 254},
#   {'lat': 35.449902,
#    'lng': 51.025475,
#    'alt': 5700,
#    'spd': 169,
#    'ts': 1692080748,
#    'hd': 263},
#   {'lat': 35.450134,
#    'lng': 51.028164,
#    'alt': 5650,
#    'spd': 170,
#    'ts': 1692080745,
#    'hd': 271},
#   {'lat': 35.450043,
#    'lng': 51.031494,
#    'alt': 5625,
#    'spd': 170,
#    'ts': 1692080742,
#    'hd': 279},
#   {'lat': 35.446564,
#    'lng': 51.045799,
#    'alt': 5350,
#    'spd': 169,
#    'ts': 1692080727,
#    'hd': 288},
#   {'lat': 35.443058,
#    'lng': 51.058025,
#    'alt': 5125,
#    'spd': 166,
#    'ts': 1692080713,
#    'hd': 289},
#   {'lat': 35.440544,
#    'lng': 51.066792,
#    'alt': 4975,
#    'spd': 163,
#    'ts': 1692080703,
#    'hd': 289},
#   {'lat': 35.438869,
#    'lng': 51.072399,
#    'alt': 4875,
#    'spd': 161,
#    'ts': 1692080696,
#    'hd': 290},
#   {'lat': 35.436356,
#    'lng': 51.080814,
#    'alt': 4650,
#    'spd': 161,
#    'ts': 1692080687,
#    'hd': 289},
#   {'lat': 35.434494,
#    'lng': 51.087303,
#    'alt': 4475,
#    'spd': 161,
#    'ts': 1692080679,
#    'hd': 288},
#   {'lat': 35.43251,
#    'lng': 51.094608,
#    'alt': 4250,
#    'spd': 162,
#    'ts': 1692080671,
#    'hd': 287},
#   {'lat': 35.430405,
#    'lng': 51.102848,
#    'alt': 4000,
#    'spd': 162,
#    'ts': 1692080661,
#    'hd': 286},
#   {'lat': 35.42886,
#    'lng': 51.109043,
#    'alt': 3850,
#    'spd': 162,
#    'ts': 1692080655,
#    'hd': 287},
#   {'lat': 35.42688,
#    'lng': 51.116581,
#    'alt': 3650,
#    'spd': 161,
#    'ts': 1692080646,
#    'hd': 287},
#   {'lat': 35.425232,
#    'lng': 51.122818,
#    'alt': 3500,
#    'spd': 161,
#    'ts': 1692080639,
#    'hd': 288},
#   {'lat': 35.42276,
#    'lng': 51.131573,
#    'alt': 3325,
#    'spd': 160,
#    'ts': 1692080630,
#    'hd': 289},
#   {'lat': 35.420853,
#    'lng': 51.138435,
#    'alt': 3125,
#    'spd': 158,
#    'ts': 1692080620,
#    'hd': 288},
#   {'lat': 35.419315,
#    'lng': 51.143871,
#    'alt': 3150,
#    'spd': 145,
#    'ts': 1692080614,
#    'hd': 288},
#   {'lat': 35.417549,
#    'lng': 51.150242,
#    'alt': 3150,
#    'spd': 119,
#    'ts': 1692080605,
#    'hd': 289},
#   {'lat': 35.416058,
#    'lng': 51.155674,
#    'alt': 3150,
#    'spd': 100,
#    'ts': 1692080597,
#    'hd': 288},
#   {'lat': 35.415047,
#    'lng': 51.159225,
#    'alt': 0,
#    'spd': 82,
#    'ts': 1692080590,
#    'hd': 289},
#   {'lat': 35.414268,
#    'lng': 51.162029,
#    'alt': 0,
#    'spd': 59,
#    'ts': 1692080583,
#    'hd': 289},
#   {'lat': 35.413765,
#    'lng': 51.163784,
#    'alt': 0,
#    'spd': 39,
#    'ts': 1692080577,
#    'hd': 289},
#   {'lat': 35.413433,
#    'lng': 51.164974,
#    'alt': 0,
#    'spd': 14,
#    'ts': 1692080570,
#    'hd': 286},
#   {'lat': 35.413368,
#    'lng': 51.165215,
#    'alt': 0,
#    'spd': 2,
#    'ts': 1692080566,
#    'hd': 286},
#   {'lat': 35.413342,
#    'lng': 51.165421,
#    'alt': 0,
#    'spd': 4,
#    'ts': 1692080540,
#    'hd': 303},
#   {'lat': 35.413254,
#    'lng': 51.165623,
#    'alt': 0,
#    'spd': 6,
#    'ts': 1692080531,
#    'hd': 343},
#   {'lat': 35.413033,
#    'lng': 51.165695,
#    'alt': 0,
#    'spd': 7,
#    'ts': 1692080523,
#    'hd': 11},
#   {'lat': 35.412811,
#    'lng': 51.165653,
#    'alt': 0,
#    'spd': 7,
#    'ts': 1692080516,
#    'hd': 16},
#   {'lat': 35.41259,
#    'lng': 51.165565,
#    'alt': 0,
#    'spd': 9,
#    'ts': 1692080510,
#    'hd': 16},
#   {'lat': 35.412357,
#    'lng': 51.165474,
#    'alt': 0,
#    'spd': 11,
#    'ts': 1692080504,
#    'hd': 19},
#   {'lat': 35.412136,
#    'lng': 51.16539,
#    'alt': 0,
#    'spd': 12,
#    'ts': 1692080500,
#    'hd': 22},
#   {'lat': 35.411865,
#    'lng': 51.165234,
#    'alt': 0,
#    'spd': 11,
#    'ts': 1692080495,
#    'hd': 47}],
#  'firstTimestamp': 1692080495,
#  's': 'PIYERwQb-kgK7fEhwkFIKQmrCEf1sihrihQVQqopyBxTkc9PSicHz0Gow4LcMdki'}

# %%
aircraft = flight_details['aircraft']
airline = flight_details['airline']

# %%
if flight_details['airport']['origin'] != None:
    origin = flight_details['airport']['origin']['name']
else:
    origin = None

if flight_details['airport']['destination'] != None:
    destination = flight_details['airport']['destination']['name']
    destination_icao = flight_details['airport']['destination']['code']['icao']
else:
    destination = None


response = flight_details['aircraft']['images']['large']
for r in response:
  curr_response = requests.get(r['src'])
  img2 = Image.open(BytesIO(curr_response.content))

  # Show the loaded image
  #img2.show()

  plt.imshow(img2,cmap='gray')
  plt.show()

# %%
if airline != None:
    print(aircraft['model']['text'], ": ", airline['name'], "/", airline['code']['icao'])
    print("{} ----> {}".format(origin, destination))
# Out:
# Airbus A340-311 :  Mahan Air / IRM
# Tehran Imam Khomeini International Airport ----> Dubai International Airport

# %%
airport = fr_api.get_airport(destination_icao)
distance = flight.get_distance_from(airport)

print("{}km".format(distance))
# Out:
# 29.63966700708839km
